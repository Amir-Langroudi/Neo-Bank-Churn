# %% [markdown]
# # ***Evaluating and cleaning the Tranactions Table***

# %%
import pandas as pd
# Display all columns
pd.set_option('display.max_columns', None)

# Display all rows
pd.set_option('display.max_rows', None)

# %%
from google.colab import auth
auth.authenticate_user()
from google.cloud import bigquery
from pandas_gbq import read_gbq


project_id = "data-analytics-bootcamp-363212"

query = '''
SELECT *
FROM `data-analytics-bootcamp-363212.neo_bank.transactions`
'''

df_transactions = read_gbq(query, project_id=project_id)
# Out:
# Downloading:  96%|█████████▌|

# %%
df_transactions.head()
# Out:
#         transaction_id transactions_type transactions_currency  amount_usd  \
# 0      transaction_505             TOPUP                   AED      298.62
# 1  transaction_1755379          EXCHANGE                   AED        3.51
# 2     transaction_1667          EXCHANGE                   AED        0.05
# 3     transaction_1429          EXCHANGE                   AED       24.14
# 4      transaction_345          EXCHANGE                   AED        0.21
#
#   transactions_state ea_cardholderpresence  ea_merchant_mcc ea_merchant_city  \
# 0          COMPLETED                  None              NaN             None
# 1          COMPLETED                  None              NaN             None
# 2          COMPLETED                  None              NaN             None
# 3          COMPLETED                  None              NaN             None
# 4          COMPLETED                  None              NaN             None
#
#   ea_merchant_country direction     user_id                     created_date
# 0                None   INBOUND   user_4773 2018-08-02 09:41:07.426363+00:00
# 1                None  OUTBOUND  user_10435 2018-09-06 10:23:15.807148+00:00
# 2                None  OUTBOUND    user_397 2018-05-16 06:09:28.063037+00:00
# 3                None  OUTBOUND   user_4399 2018-12-19 20:22:03.550130+00:00
# 4                None  OUTBOUND   user_1731 2018-10-27 13:29:56.524826+00:00

# %%
df_transactions.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2740075 entries, 0 to 2740074
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   transaction_id         2740075 non-null  object
#  1   transactions_type      2740075 non-null  object
#  2   transactions_currency  2740075 non-null  object
#  3   amount_usd             2740075 non-null  float64
#  4   transactions_state     2740075 non-null  object
#  5   ea_cardholderpresence  1569481 non-null  object
#  6   ea_merchant_mcc        1581417 non-null  float64
#  7   ea_merchant_city       1581281 non-null  object
#  8   ea_merchant_country    1581096 non-null  object
#  9   direction              2740075 non-null  object
#  10  user_id                2740075 non-null  object
#  11  created_date           2740075 non-null  datetime64[us, UTC]
# dtypes: datetime64[us, UTC](1), float64(2), object(9)
# memory usage: 250.9+ MB

# %%
df_transactions.isnull().sum()
# Out:
# transaction_id                 0
# transactions_type              0
# transactions_currency          0
# amount_usd                     0
# transactions_state             0
# ea_cardholderpresence    1170594
# ea_merchant_mcc          1158658
# ea_merchant_city         1158794
# ea_merchant_country      1158979
# direction                      0
# user_id                        0
# created_date                   0
# dtype: int64

# %%
df_transactions.nunique()
# Out:
# transaction_id           2740075
# transactions_type             10
# transactions_currency         35
# amount_usd                 48548
# transactions_state             6
# ea_cardholderpresence          3
# ea_merchant_mcc              664
# ea_merchant_city           63253
# ea_merchant_country          198
# direction                      2
# user_id                    18766
# created_date             2739658
# dtype: int64

# %%
cols = ['ea_cardholderpresence','ea_merchant_city', 'ea_merchant_country']
df_transactions[cols] = df_transactions[cols].fillna('unknown')
df_transactions['ea_merchant_mcc'] = df_transactions['ea_merchant_mcc'].fillna(0)

# %%
df_transactions.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2740075 entries, 0 to 2740074
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   transaction_id         2740075 non-null  object
#  1   transactions_type      2740075 non-null  object
#  2   transactions_currency  2740075 non-null  object
#  3   amount_usd             2740075 non-null  float64
#  4   transactions_state     2740075 non-null  object
#  5   ea_cardholderpresence  2740075 non-null  object
#  6   ea_merchant_mcc        2740075 non-null  float64
#  7   ea_merchant_city       2740075 non-null  object
#  8   ea_merchant_country    2740075 non-null  object
#  9   direction              2740075 non-null  object
#  10  user_id                2740075 non-null  object
#  11  created_date           2740075 non-null  datetime64[us, UTC]
# dtypes: datetime64[us, UTC](1), float64(2), object(9)
# memory usage: 250.9+ MB

# %%
df_transactions.head()
# Out:
#         transaction_id transactions_type transactions_currency  amount_usd  \
# 0      transaction_505             TOPUP                   AED      298.62
# 1  transaction_1755379          EXCHANGE                   AED        3.51
# 2     transaction_1667          EXCHANGE                   AED        0.05
# 3     transaction_1429          EXCHANGE                   AED       24.14
# 4      transaction_345          EXCHANGE                   AED        0.21
#
#   transactions_state ea_cardholderpresence  ea_merchant_mcc ea_merchant_city  \
# 0          COMPLETED               unknown              0.0          unknown
# 1          COMPLETED               unknown              0.0          unknown
# 2          COMPLETED               unknown              0.0          unknown
# 3          COMPLETED               unknown              0.0          unknown
# 4          COMPLETED               unknown              0.0          unknown
#
#   ea_merchant_country direction     user_id                     created_date
# 0             unknown   INBOUND   user_4773 2018-08-02 09:41:07.426363+00:00
# 1             unknown  OUTBOUND  user_10435 2018-09-06 10:23:15.807148+00:00
# 2             unknown  OUTBOUND    user_397 2018-05-16 06:09:28.063037+00:00
# 3             unknown  OUTBOUND   user_4399 2018-12-19 20:22:03.550130+00:00
# 4             unknown  OUTBOUND   user_1731 2018-10-27 13:29:56.524826+00:00

# %%
df_transactions.columns = df_transactions.columns.str.lower().str.replace(" ", "_")
text_cols = df_transactions.select_dtypes(include='object').columns

for col in text_cols:
    df_transactions[col] = (df_transactions[col].str.lower() .str.strip().str.replace(r'\s+', '_', regex=True) .str.replace(r'[^\w]', '', regex=True))

# %%
df_transactions.head()
# Out:
#         transaction_id transactions_type transactions_currency  amount_usd  \
# 0      transaction_505             topup                   aed      298.62
# 1  transaction_1755379          exchange                   aed        3.51
# 2     transaction_1667          exchange                   aed        0.05
# 3     transaction_1429          exchange                   aed       24.14
# 4      transaction_345          exchange                   aed        0.21
#
#   transactions_state ea_cardholderpresence  ea_merchant_mcc ea_merchant_city  \
# 0          completed               unknown              0.0          unknown
# 1          completed               unknown              0.0          unknown
# 2          completed               unknown              0.0          unknown
# 3          completed               unknown              0.0          unknown
# 4          completed               unknown              0.0          unknown
#
#   ea_merchant_country direction     user_id                     created_date
# 0             unknown   inbound   user_4773 2018-08-02 09:41:07.426363+00:00
# 1             unknown  outbound  user_10435 2018-09-06 10:23:15.807148+00:00
# 2             unknown  outbound    user_397 2018-05-16 06:09:28.063037+00:00
# 3             unknown  outbound   user_4399 2018-12-19 20:22:03.550130+00:00
# 4             unknown  outbound   user_1731 2018-10-27 13:29:56.524826+00:00

# %%
df_transactions[df_transactions.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [transaction_id, transactions_type, transactions_currency, amount_usd, transactions_state, ea_cardholderpresence, ea_merchant_mcc, ea_merchant_city, ea_merchant_country, direction, user_id, created_date]
# Index: []

# %%
df_transactions.tail(20)
# Out:
#               transaction_id transactions_type transactions_currency  \
# 2740055    transaction_89344      card_payment                   zar
# 2740056  transaction_1810046      card_payment                   zar
# 2740057    transaction_88964      card_payment                   zar
# 2740058  transaction_1810045      card_payment                   zar
# 2740059  transaction_1846231      card_payment                   zar
# 2740060  transaction_1809880      card_payment                   zar
# 2740061  transaction_1846551      card_payment                   zar
# 2740062   transaction_227975      card_payment                   zar
# 2740063  transaction_1846398      card_payment                   zar
# 2740064  transaction_1846752      card_payment                   zar
# 2740065   transaction_227606      card_payment                   zar
# 2740066   transaction_234281      card_payment                   zar
# 2740067    transaction_89634      card_payment                   zar
# 2740068  transaction_1809496      card_payment                   zar
# 2740069    transaction_89994      card_payment                   zar
# 2740070  transaction_1846531      card_payment                   zar
# 2740071    transaction_89554      card_payment                   zar
# 2740072    transaction_89359      card_payment                   zar
# 2740073   transaction_228016      card_payment                   zar
# 2740074  transaction_1846516      card_payment                   zar
#
#          amount_usd transactions_state ea_cardholderpresence  ea_merchant_mcc  \
# 2740055       29.62          completed                 false           5812.0
# 2740056       37.02          completed                 false           5812.0
# 2740057        0.20          completed                 false           5812.0
# 2740058        4.23          completed                 false           5812.0
# 2740059        3.54          completed                 false           5812.0
# 2740060       14.54          completed                 false           5812.0
# 2740061        2.12          completed                 false           5813.0
# 2740062       15.87          completed                 false           5813.0
# 2740063       23.80          completed                 false           5813.0
# 2740064        0.00           reverted                 false           7349.0
# 2740065       12.51          completed                 false           5814.0
# 2740066        4.53          completed                 false           5814.0
# 2740067        1.06          completed                 false           5814.0
# 2740068       37.97          completed                 false           5309.0
# 2740069       14.28          completed                 false           4812.0
# 2740070       18.51          completed                 false            763.0
# 2740071       83.78          completed                 false           5621.0
# 2740072        9.47          completed                 false           5621.0
# 2740073       13.22          completed                 false           5621.0
# 2740074       65.48          completed                  true           8699.0
#
#         ea_merchant_city ea_merchant_country direction     user_id  \
# 2740055       mossel_bay                 zaf  outbound   user_1805
# 2740056      green_point                 zaf  outbound  user_10145
# 2740057     johannesburg                 zaf  outbound   user_3017
# 2740058        nelspruit                 zaf  outbound  user_15106
# 2740059           durban                 zaf  outbound  user_13647
# 2740060         hout_bay                 zaf  outbound  user_19085
# 2740061           durban                 zaf  outbound  user_13647
# 2740062     johannesburg                 zaf  outbound   user_2818
# 2740063    cape_town_cbd                 zaf  outbound  user_18197
# 2740064           avalon                 aus  outbound  user_12577
# 2740065        camps_bay                 zaf  outbound    user_598
# 2740066          ormonde                 zaf  outbound   user_3317
# 2740067        table_bay                 zaf  outbound   user_4472
# 2740068     johannesburg                 zaf  outbound  user_13647
# 2740069      sunninghill                 zaf  outbound   user_1438
# 2740070      franschhoek                 zaf  outbound  user_17834
# 2740071         hermanus                 zaf  outbound   user_5940
# 2740072        cape_town                 zaf  outbound   user_4408
# 2740073           durban                 zaf  outbound   user_2777
# 2740074        cape_town                 zaf  outbound  user_10355
#
#                             created_date
# 2740055 2018-12-30 03:12:48.330871+00:00
# 2740056 2018-11-28 09:02:48.654125+00:00
# 2740057 2019-01-17 10:26:11.171715+00:00
# 2740058 2018-11-28 07:52:29.879505+00:00
# 2740059 2018-12-19 02:12:20.070997+00:00
# 2740060 2019-04-04 18:57:33.377703+00:00
# 2740061 2018-10-27 11:28:21.753997+00:00
# 2740062 2018-05-12 09:19:52.595898+00:00
# 2740063 2019-03-17 13:55:44.563988+00:00
# 2740064 2018-11-07 12:40:24.093874+00:00
# 2740065 2018-11-26 16:55:18.486427+00:00
# 2740066 2019-04-08 00:56:44.703810+00:00
# 2740067 2019-01-14 15:02:28.345079+00:00
# 2740068 2018-12-23 13:55:24.697997+00:00
# 2740069 2018-09-11 11:49:37.048606+00:00
# 2740070 2019-01-11 16:23:15.426372+00:00
# 2740071 2019-02-05 05:21:32.306479+00:00
# 2740072 2019-04-22 16:23:47.270808+00:00
# 2740073 2018-07-06 14:14:01.922242+00:00
# 2740074 2019-01-26 22:05:54.452258+00:00

# %% [markdown]
# # ***Evaluating and cleaning the Notifications Table***
#
#
# ---

# %%
from google.colab import auth
auth.authenticate_user()
from google.cloud import bigquery
import pandas as pd
from pandas_gbq import read_gbq


project_id = "data-analytics-bootcamp-363212"

query = '''
SELECT *
FROM `data-analytics-bootcamp-363212.neo_bank.notifications`
'''

df_notifications = read_gbq(query, project_id=project_id)
# Out:
# Downloading: 100%|██████████|

# %%
df_notifications.head()
# Out:
#                reason channel status    user_id  \
# 0  METAL_RESERVE_PLAN     SMS   SENT  user_4703
# 1  METAL_RESERVE_PLAN     SMS   SENT  user_2397
# 2  METAL_RESERVE_PLAN     SMS   SENT  user_2411
# 3  METAL_RESERVE_PLAN     SMS   SENT  user_1119
# 4  METAL_RESERVE_PLAN     SMS   SENT  user_3499
#
#                       created_date
# 0 2018-10-14 01:48:13.319987+00:00
# 1 2018-10-17 08:07:05.709072+00:00
# 2 2018-10-14 03:46:34.244392+00:00
# 3 2018-10-14 14:16:35.801185+00:00
# 4 2018-10-14 18:41:09.268675+00:00

# %%
df_notifications.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121813 entries, 0 to 121812
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   reason        121813 non-null  object
#  1   channel       121813 non-null  object
#  2   status        121813 non-null  object
#  3   user_id       121813 non-null  object
#  4   created_date  121813 non-null  datetime64[us, UTC]
# dtypes: datetime64[us, UTC](1), object(4)
# memory usage: 4.6+ MB

# %%
df_notifications.nunique()
# Out:
# reason              17
# channel              3
# status               2
# user_id          18953
# created_date    121810
# dtype: int64

# %%
df_notifications.columns = df_notifications.columns.str.lower().str.replace(" ", "_")
text_cols = df_notifications.select_dtypes(include='object').columns

for col in text_cols:
    df_notifications[col] = (df_notifications[col].str.lower() .str.strip().str.replace(r'\s+', '_', regex=True) .str.replace(r'[^\w]', '', regex=True))

# %%
df_notifications.head()
# Out:
#                reason channel status    user_id  \
# 0  metal_reserve_plan     sms   sent  user_4703
# 1  metal_reserve_plan     sms   sent  user_2397
# 2  metal_reserve_plan     sms   sent  user_2411
# 3  metal_reserve_plan     sms   sent  user_1119
# 4  metal_reserve_plan     sms   sent  user_3499
#
#                       created_date
# 0 2018-10-14 01:48:13.319987+00:00
# 1 2018-10-17 08:07:05.709072+00:00
# 2 2018-10-14 03:46:34.244392+00:00
# 3 2018-10-14 14:16:35.801185+00:00
# 4 2018-10-14 18:41:09.268675+00:00

# %%
df_notifications[df_notifications.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [reason, channel, status, user_id, created_date]
# Index: []

# %%
df_notifications.tail(40)
